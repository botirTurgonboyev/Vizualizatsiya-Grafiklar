# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ushbu amaliyot uchun https://en.tutiempo.net/climate/ws-384570.html sahifasidagi Toshkent shahri o'rtacha havo harorati haqidagi ma'lumotlardan foydalanamiz.

# %%
#@title QUYIDAGI KODGA TEGMANG!!!
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = pd.read_html('https://en.tutiempo.net/climate/ws-384570.html')
df = data[0]
df
# Out:
#     Year     T    TM    Tm PP    V   RA  SN  TS  FG TN GR
# 0   1933     -     -     -  -    -    -   -   -   -  -  -
# 1   1934     -     -     -  -    -    -   -   -   -  -  -
# 2   1935     -     -     -  -    -    -   -   -   -  -  -
# 3   1936     -     -     -  -    -    -   -   -   -  -  -
# 4   1937     -     -     -  -    -    -   -   -   -  -  -
# ..   ...   ...   ...   ... ..  ...  ...  ..  ..  .. .. ..
# 77  2021    17  23.4  10.1  -   10   82  11  10  14  0  0
# 78  2022  16.7  22.6  10.2  -  9.8  115  17  14  32  0  0
# 79  2023  17.3  23.6  10.4  -   10   96  15  14  19  0  0
# 80  2024     -     -     -  -    -    -   -   -   -  -  -
# 81  2025     -     -     -  -    -    -   -   -   -  -  -
#
# [82 rows x 12 columns]

# %%
df.index = df['Year']

# %%
df = df[df['Year'] > 1989]
df
# Out:
#       Year     T    TM    Tm      PP    V   RA  SN  TS  FG TN GR
# Year
# 1990  1990  14.9  21.5   8.7  504.72  5.1   84  32  12  12  0  1
# 1991  1991  14.4  21.2   8.3  460.52  5.1   77  26  15  17  0  1
# 1992  1992  14.4  20.8   8.6  470.39  5.1   93  19   9   2  0  1
# 1993  1993  13.4  19.6   7.6  710.97  5.4   98  38  12  10  1  0
# 1994  1994  14.4  21.1     8  595.38  5.1   66  28   4   9  0  0
# 1995  1995    15  22.2   8.4  189.99  4.4   41  20   8  12  0  0
# 1996  1996    14  20.5   7.6  184.16    5   68  23  14  13  0  0
# 1997  1997     -     -     -       -    -    -   -   -   -  -  -
# 1998  1998     -     -     -       -    -    -   -   -   -  -  -
# 1999  1999  15.7  22.4   8.9  524.21  7.6   98  15  13  18  0  0
# 2000  2000    16  22.5   9.1       -    8   84  19  11  25  0  2
# 2001  2001  16.3  22.7   9.2       -  8.2   80  20  12  23  1  0
# 2002  2002     -     -     -       -    -   92  35  13  28  0  0
# ...

# %%
df.drop('Year', axis=1, inplace=True)
df
# Out:
# /tmp/ipykernel_609/787922991.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('Year', axis=1, inplace=True)
#          T    TM    Tm      PP    V   RA  SN  TS  FG TN GR
# Year
# 1990  14.9  21.5   8.7  504.72  5.1   84  32  12  12  0  1
# 1991  14.4  21.2   8.3  460.52  5.1   77  26  15  17  0  1
# 1992  14.4  20.8   8.6  470.39  5.1   93  19   9   2  0  1
# 1993  13.4  19.6   7.6  710.97  5.4   98  38  12  10  1  0
# 1994  14.4  21.1     8  595.38  5.1   66  28   4   9  0  0
# 1995    15  22.2   8.4  189.99  4.4   41  20   8  12  0  0
# 1996    14  20.5   7.6  184.16    5   68  23  14  13  0  0
# 1997     -     -     -       -    -    -   -   -   -  -  -
# 1998     -     -     -       -    -    -   -   -   -  -  -
# 1999  15.7  22.4   8.9  524.21  7.6   98  15  13  18  0  0
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data[1]
# Out:
#      0                                        1
# 0    T          Average annual temperature (°C)
# 1   TM  Annual average maximum temperature (°C)
# 2   Tm  Average annual minimum temperature (°C)
# 3   PP  Rain or snow precipitation total annual
# 4    V         Annual average wind speed (km/h)
# 5   RA                 Number of days with rain
# 6   SN                 Number of days with snow
# 7   TS                Number of days with storm
# 8   FG                     Number of foggy days
# 9   TN              Number of days with tornado
# 10  GR                 Number of days with hail

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 1990 to 2025
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       36 non-null     object
#  1   TM      36 non-null     object
#  2   Tm      36 non-null     object
#  3   PP      36 non-null     object
#  4   V       36 non-null     object
#  5   RA      36 non-null     object
#  6   SN      36 non-null     object
#  7   TS      36 non-null     object
#  8   FG      36 non-null     object
#  9   TN      36 non-null     object
#  10  GR      36 non-null     object
# dtypes: object(11)
# memory usage: 3.4+ KB

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#sonlar object bo'lib qolgan

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.replace('-', np.nan)
# Out:
#          T    TM    Tm      PP    V   RA   SN   TS   FG   TN   GR
# Year
# 1990  14.9  21.5   8.7  504.72  5.1   84   32   12   12    0    1
# 1991  14.4  21.2   8.3  460.52  5.1   77   26   15   17    0    1
# 1992  14.4  20.8   8.6  470.39  5.1   93   19    9    2    0    1
# 1993  13.4  19.6   7.6  710.97  5.4   98   38   12   10    1    0
# 1994  14.4  21.1     8  595.38  5.1   66   28    4    9    0    0
# 1995    15  22.2   8.4  189.99  4.4   41   20    8   12    0    0
# 1996    14  20.5   7.6  184.16    5   68   23   14   13    0    0
# 1997   NaN   NaN   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1998   NaN   NaN   NaN     NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1999  15.7  22.4   8.9  524.21  7.6   98   15   13   18    0    0
# 2000    16  22.5   9.1     NaN    8   84   19   11   25    0    2
# 2001  16.3  22.7   9.2     NaN  8.2   80   20   12   23    1    0
# 2002   NaN   NaN   NaN     NaN  NaN   92   35   13   28    0    0
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = df.replace('-', np.nan)
df = df.astype(dtype = 'float')
df
# Out:
#          T    TM    Tm      PP     V     RA    SN    TS    FG   TN   GR
# Year
# 1990  14.9  21.5   8.7  504.72   5.1   84.0  32.0  12.0  12.0  0.0  1.0
# 1991  14.4  21.2   8.3  460.52   5.1   77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8   8.6  470.39   5.1   93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6   7.6  710.97   5.4   98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1   8.0  595.38   5.1   66.0  28.0   4.0   9.0  0.0  0.0
# 1995  15.0  22.2   8.4  189.99   4.4   41.0  20.0   8.0  12.0  0.0  0.0
# 1996  14.0  20.5   7.6  184.16   5.0   68.0  23.0  14.0  13.0  0.0  0.0
# 1997   NaN   NaN   NaN     NaN   NaN    NaN   NaN   NaN   NaN  NaN  NaN
# 1998   NaN   NaN   NaN     NaN   NaN    NaN   NaN   NaN   NaN  NaN  NaN
# 1999  15.7  22.4   8.9  524.21   7.6   98.0  15.0  13.0  18.0  0.0  0.0
# 2000  16.0  22.5   9.1     NaN   8.0   84.0  19.0  11.0  25.0  0.0  2.0
# 2001  16.3  22.7   9.2     NaN   8.2   80.0  20.0  12.0  23.0  1.0  0.0
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.isna().sum()
# Out:
# T      6
# TM     6
# Tm     6
# PP    26
# V      6
# RA     5
# SN     5
# TS     5
# FG     5
# TN     5
# GR     5
# dtype: int64

# %%
df.isna().mean()*100
# Out:
# T     16.666667
# TM    16.666667
# Tm    16.666667
# PP    72.222222
# V     16.666667
# RA    13.888889
# SN    13.888889
# TS    13.888889
# FG    13.888889
# TN    13.888889
# GR    13.888889
# dtype: float64

# %%
df.drop(df.isna().mean().idxmax(), axis=1, inplace=True)

# %%
df.head()
# Out:
#          T    TM   Tm    V    RA    SN    TS    FG   TN   GR
# Year
# 1990  14.9  21.5  8.7  5.1  84.0  32.0  12.0  12.0  0.0  1.0
# 1991  14.4  21.2  8.3  5.1  77.0  26.0  15.0  17.0  0.0  1.0
# 1992  14.4  20.8  8.6  5.1  93.0  19.0   9.0   2.0  0.0  1.0
# 1993  13.4  19.6  7.6  5.4  98.0  38.0  12.0  10.0  1.0  0.0
# 1994  14.4  21.1  8.0  5.1  66.0  28.0   4.0   9.0  0.0  0.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.isna().sum()
# Out:
# T     6
# TM    6
# Tm    6
# V     6
# RA    5
# SN    5
# TS    5
# FG    5
# TN    5
# GR    5
# dtype: int64

# %%
df.shape
# Out:
# (36, 10)

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_609/3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.to_csv('data.csv')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = df['T']
x.head()
# Out:
# Year
# 1990    14.9
# 1991    14.4
# 1992    14.4
# 1993    13.4
# 1994    14.4
# Name: T, dtype: float64

# %%
plt.plot(x)
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.plot(x, linewidth=3, color='r', linestyle=':')
plt.show()

# %%
plt.plot(x, linewidth=3, color='r', linestyle=':', marker='v')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(x, linewidth=3, color='r', linestyle=':', marker='v')
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.figure(figsize=(10, 5))
plt.plot(x, linewidth=3, linestyle='--', marker='h', markerfacecolor='r')
plt.xlabel('Yillar')
plt.ylabel("O'rtacha harorat")
plt.title("Yillardagi o'rtacha harorat")
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from IPython.display import Image

# %%
xmax = df['TM']
xmax.head()
# Out:
# Year
# 1990    21.5
# 1991    21.2
# 1992    20.8
# 1993    19.6
# 1994    21.1
# Name: TM, dtype: float64

# %%
xmin = df['Tm']
xmin.head()
# Out:
# Year
# 1990    8.7
# 1991    8.3
# 1992    8.6
# 1993    7.6
# 1994    8.0
# Name: Tm, dtype: float64

# %%
plt.figure(figsize=(13, 6))
plt.title("O'rtacha maksimum va minum haroratlar")
plt.xlabel('Yillar')
plt.ylabel('Harorat')
plt.plot(xmax, linewidth=2, linestyle='--', marker='h', markerfacecolor='r')
plt.plot(xmin, linewidth=3, linestyle=':', marker='v', markerfacecolor='b')
plt.legend(['Maksimum', 'Minimum'])
plt.savefig('max_va_min_grafik.png')
plt.show()

# %%
Image('max_va_min_grafik.png')
